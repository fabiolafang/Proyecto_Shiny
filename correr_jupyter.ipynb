# %%
# !shiny run --reload pelis_app.py
# Out:
# INFO:     Will watch for changes in these directories: ['/Users/cataxmonger7/Downloads']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [25061] using WatchFiles
# INFO:     Started server process [25063]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:52517 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52522 - "WebSocket /websocket/" [accepted]
# INFO:     connection open
# INFO:     connection closed
