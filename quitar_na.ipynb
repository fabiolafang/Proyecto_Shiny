# %%
import pandas as pd

# %%
df = pd.read_excel("base_ajustada.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9952 entries, 0 to 9951
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              9952 non-null   object
#  1   vote_average       9952 non-null   float64
#  2   vote_count         9952 non-null   int64
#  3   revenue            9952 non-null   int64
#  4   budget             5481 non-null   float64
#  5   popularity         9952 non-null   float64
#  6   runtime            9845 non-null   float64
#  7   genre              9952 non-null   object
#  8   language           9952 non-null   object
#  9   country            9952 non-null   object
#  10  revenue_mill       9952 non-null   float64
#  11  budget_mill        5481 non-null   float64
#  12  genre_random       9832 non-null   object
#  13  country_random     9952 non-null   object
#  14  language_adj       9952 non-null   object
#  15  country_continent  9922 non-null   object
# ...

# %%
df.dropna().shape
# Out:
# (5454, 16)

# %%
df.dropna().shape[0]
# Out:
# 5454

# %%
df_completa = df.dropna()

# %%
df_completa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5454 entries, 0 to 9950
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              5454 non-null   object
#  1   vote_average       5454 non-null   float64
#  2   vote_count         5454 non-null   int64
#  3   revenue            5454 non-null   int64
#  4   budget             5454 non-null   float64
#  5   popularity         5454 non-null   float64
#  6   runtime            5454 non-null   float64
#  7   genre              5454 non-null   object
#  8   language           5454 non-null   object
#  9   country            5454 non-null   object
#  10  revenue_mill       5454 non-null   float64
#  11  budget_mill        5454 non-null   float64
#  12  genre_random       5454 non-null   object
#  13  country_random     5454 non-null   object
#  14  language_adj       5454 non-null   object
#  15  country_continent  5454 non-null   object
# ...

# %%
df_completa.to_excel("base_completa.xlsx", index=False)
